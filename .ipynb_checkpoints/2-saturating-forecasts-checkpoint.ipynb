# %% [markdown]
# <h2 style="font-family: Arial, sans-serif; margin-bottom: 10px;">Doyuma Ulaşan Tahminler</h2>
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     <strong>Büyüme Tahmini</strong><br>
#     Prophet, varsayılan olarak tahminler için doğrusal bir model kullanır. Ancak, gerçek dünyada büyümenin bir sınırı vardır.
#     Örneğin, bir pazarın toplam büyüklüğü ya da bir web sitesinin erişebileceği maksimum kullanıcı sayısı gibi.
#     Bu sınıra <strong>taşıma kapasitesi</strong> (carrying capacity) denir ve tahminlerin bu noktaya ulaştığında doyuma varması beklenir.
# </font>
#
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     Prophet, taşıma kapasitesini dikkate alarak tahmin yapmanızı sağlayan <strong>lojistik büyüme trend modeli</strong>ni destekler.
#     Bu model, büyümenin zamanla yavaşlayarak belirli bir maksimum değere ulaşacağını öngörür.
#     Bunu, Wikipedia'daki
#     <a href="https://en.wikipedia.org/wiki/R_%28programming_language%29" target="_blank" style="color: blue; text-decoration: none;">R (programlama dili)</a>
#     sayfasının ziyaret sayılarının logaritmik büyümesini kullanarak örnekleyeceğiz.
# </font>

# %%
import pandas as pd
from prophet import Prophet

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')

# %%
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %% [markdown]
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     Taşıma kapasitesini belirtmek için veride bir <strong>cap</strong> sütunu oluşturmalıyız.
#     Bu kapasite genellikle pazar büyüklüğü veya maksimum değer gibi bilgilere dayanarak belirlenir.
#     Örneğin, veri setindeki hedef değişkenin maksimum değerine dayanarak taşıma kapasitesini şöyle belirleyebiliriz:
# </font>

# %%
max_value = df['y'].max()  # Maksimum değer
df['cap'] = max_value * 1.1

# %% [markdown]
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     Bu örnekte, maksimum değerin biraz üzerine çıkacak şekilde taşıma kapasitesi tanımlanmıştır.
#     Ancak gerçek uygulamalarda bu değer, pazar büyüklüğü veya <strong>uzman görüşüne</strong> göre ayarlanmalıdır.
# </font>

# %% [markdown]
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     Modeli daha önceki adımlarda olduğu gibi eğitebiliriz, ancak bu kez lojistik büyümeyi belirtmek için ek bir parametre geçmemiz gerekiyor:
#     <strong>growth</strong> parametresi. Bu parametre, büyüme modelini belirler ve <strong>'logistic'</strong> olarak ayarlandığında
#     lojistik büyüme modelini kullanmamızı sağlar. Ayrıca, taşıma kapasitesini belirtmek için <strong>cap</strong> sütununu da
#     kullanmamız gerekiyor.
# </font>

# %%
m = Prophet(growth='logistic')
m.fit(df)
# Out:
# 15:36:17 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:17 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     Burada, kapasiteyi geçmişte belirlediğimiz değerde sabit tutuyoruz ve 5 yıl ileriye dönük tahmin yapıyoruz:
# </font>

# %%
# Python
future = m.make_future_dataframe(periods=5 * 365)
future['cap'] =  max_value * 1.1
fcst = m.predict(future)
fig = m.plot(fcst)

# %% [markdown]
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
#     Prophet modelinde, lojistik büyüme fonksiyonu varsayılan olarak 0 ile başlar ve taşıma kapasitesine ulaşır. Ancak, büyümenin alt sınırını değiştirmek için
#     <strong>floor</strong> parametresi kullanılabilir. Bu parametre, büyümenin alt sınırını belirler ve modelin bu değerin altına düşmesini engeller.
# </font>

# %% [markdown]
# <h2 style="font-family: Arial, sans-serif; margin-bottom: 10px;">Doyma Minimumu</h2>
#
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
# Lojistik büyüme modeli, bir <strong>doygunluk minimumu</strong> da işleyebilir. Bu minimum, maksimum değeri belirlemek için kullandığımız <strong>cap</strong> sütununa benzer şekilde, <strong>floor</strong> sütunu ile belirtilir.
# </font>

# %%
df['y'] = df['y'].max() - df['y']

new_max_value = df['y'].max()

df['cap'] =  new_max_value * 1.1
df['floor'] =  0.5
future['cap'] = new_max_value * 1.1
future['floor'] = 0.5
m = Prophet(growth='logistic')
m.fit(df)
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# 15:36:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:36:46 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# <font size="4" style="padding: 10px; font-family: Arial, sans-serif; line-height: 1.6; display: block; margin-bottom: 15px; text-align: justify;">
# Bir lojistik büyüme trendi kullanmak ve doygunluk minimumu uygulamak için, aynı zamanda bir maksimum kapasite de belirtilmelidir. Bu işlemde, grafiği ters çevirmek için, hedef değişkenin (y) maksimum değerinden çıkarılma işlemi yapılmıştır. Bu sayede, verilerin büyüme eğilimindeki yön değiştirilir ve grafik tersine çevrilmiş olur. Yani, büyüme yerine azalma eğilimi elde edilir. Bu tür bir işlem, verilerin analizine farklı bir perspektif ekler ve modelin tahminlerinin ters yönde gözlemlenmesini sağlar.
# </font>
